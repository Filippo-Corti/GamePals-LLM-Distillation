# %%
import requests


url = "https://lovelace.ewlab.di.unimi.it/ollama/api/generate"

r = requests.post(
    url,
    auth=("filippo", "w78pS37Q8mpCUhPfEIN"),
    json={
        "model": "gemma3:12b",
        "prompt": "Why is the sky red?",
        "stream": False
    }
)

print(r.status_code)
print(r.text)
# Out:
# 200
# ...
